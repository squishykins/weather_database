# %%
# Import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90, high = 90, size=1500)

lngs = np.random.uniform(low=-90, high = 90, size=1500)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the coordinates to a list

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities

cities = []

# Identify the nearest city for each latitude and longitude combination

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, add it to the cities list
    
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 651

# %%
#starting URL for weather map API Call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data

city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")

print("-----------------------------")

# Create counters

record_count = 1

set_count = 1

# Loop through all the cities in our list.

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    
    if (i%50 == 0 and i>= 50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)
        
    # Create endpoint url with each city
    
    city_url = url+"&q="+city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    
    record_count += 1
    
# Run an api request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard
        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list
        
        city_data.append({"City":city.title(),
                         "Lat": city_lat,
                         "Lng":city_lng,
                         "Max Temp":city_max_temp,
                         "Humidity":city_humidity,
                         "Cloudiness":city_clouds,
                         "Wind Speed":city_wind,
                         "Country":city_country,
                         "Date":city_date})
# If an error is experienced, skip the city
    except:
        print("City not found. Skiping...")
        
        pass
    
# Indicate that Data Loading is complete.

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | salinopolis
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | marcona
# City not found. Skiping...
# Processing Record 6 of Set 1 | kushchevskaya
# Processing Record 7 of Set 1 | praia da vitoria
# Processing Record 8 of Set 1 | maniitsoq
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skiping...
# Processing Record 10 of Set 1 | vestmannaeyjar
# Processing Record 11 of Set 1 | puerto quijarro
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | rio grande
# Processing Record 14 of Set 1 | caxias
# Processing Record 15 of Set 1 | kruisfontein
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | bereda
# Processing Record 18 of Set 1 | taoudenni
# Processing Record 19 of Set 1 | axim
# Processing Record 20 of Set 1 | ancud
# Processing Record 21 of Set 1 | ifanadiana
# Processing Record 22 of Set 1 | victoria
# Processing Record 23 of Set 1 | saldanha
# Processing Record 24 of Set 1 | porto novo
# Processing Record 25 of Set 1 | dikson
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | barentsburg
# City not found. Skiping...
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | sisimiut
# Processing Record 30 of Set 1 | ikalamavony
# Processing Record 31 of Set 1 | trairi
# Processing Record 32 of Set 1 | colquechaca
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skiping...
# Processing Record 34 of Set 1 | maceio
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | clyde river
# Processing Record 37 of Set 1 | longyearbyen
# Processing Record 38 of Set 1 | louisbourg
# City not found. Skiping...
# Processing Record 39 of Set 1 | arys
# Processing Record 40 of Set 1 | qasigiannguit
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | lakselv
# Processing Record 44 of Set 1 | saint-joseph
# Processing Record 45 of Set 1 | raudeberg
# Processing Record 46 of Set 1 | manyoni
# Processing Record 47 of Set 1 | itaqui
# Processing Record 48 of Set 1 | tirat karmel
# Processing Record 49 of Set 1 | cidreira
# Processing Record 50 of Set 1 | lisakovsk
# Processing Record 1 of Set 2 | ostrovnoy
# Processing Record 2 of Set 2 | henties bay
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | benghazi
# Processing Record 6 of Set 2 | sorland
# Processing Record 7 of Set 2 | kenmare
# Processing Record 8 of Set 2 | brae
# Processing Record 9 of Set 2 | codrington
# Processing Record 10 of Set 2 | marsh harbour
# Processing Record 11 of Set 2 | jaunjelgava
# Processing Record 12 of Set 2 | pisco
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | kurikka
# Processing Record 17 of Set 2 | meulaboh
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skiping...
# Processing Record 19 of Set 2 | paamiut
# Processing Record 20 of Set 2 | wiarton
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | maragogi
# Processing Record 23 of Set 2 | kuminskiy
# Processing Record 24 of Set 2 | itarema
# Processing Record 25 of Set 2 | richards bay
# Processing Record 26 of Set 2 | joao pinheiro
# Processing Record 27 of Set 2 | bouca
# Processing Record 28 of Set 2 | piazza armerina
# Processing Record 29 of Set 2 | yabassi
# Processing Record 30 of Set 2 | pfaffikon
# Processing Record 31 of Set 2 | bonthe
# Processing Record 32 of Set 2 | vardo
# Processing Record 33 of Set 2 | wladyslawowo
# Processing Record 34 of Set 2 | umzimvubu
# City not found. Skiping...
# Processing Record 35 of Set 2 | quatre cocos
# Processing Record 36 of Set 2 | port-gentil
# Processing Record 37 of Set 2 | acarau
# Processing Record 38 of Set 2 | polyarnyy
# Processing Record 39 of Set 2 | carnot
# Processing Record 40 of Set 2 | wawa
# Processing Record 41 of Set 2 | los llanos de aridane
# Processing Record 42 of Set 2 | morant bay
# Processing Record 43 of Set 2 | cockburn town
# Processing Record 44 of Set 2 | boksitogorsk
# Processing Record 45 of Set 2 | santarem
# Processing Record 46 of Set 2 | chapais
# Processing Record 47 of Set 2 | san cristobal
# Processing Record 48 of Set 2 | laguna
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | grand river south east
# City not found. Skiping...
# Processing Record 1 of Set 3 | durg
# Processing Record 2 of Set 3 | gerash
# Processing Record 3 of Set 3 | faya
# Processing Record 4 of Set 3 | wa
# City not found. Skiping...
# Processing Record 5 of Set 3 | klaksvik
# Processing Record 6 of Set 3 | pangnirtung
# Processing Record 7 of Set 3 | itapuranga
# Processing Record 8 of Set 3 | dzhusaly
# City not found. Skiping...
# Processing Record 9 of Set 3 | borujerd
# Processing Record 10 of Set 3 | mahajanga
# Processing Record 11 of Set 3 | tasiilaq
# Processing Record 12 of Set 3 | luderitz
# Processing Record 13 of Set 3 | morros
# Processing Record 14 of Set 3 | tromso
# Processing Record 15 of Set 3 | leh
# Processing Record 16 of Set 3 | nanortalik
# Processing Record 17 of Set 3 | chuy
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | dharchula
# Processing Record 20 of Set 3 | tiznit
# Processing Record 21 of Set 3 | paita
# Processing Record 22 of Set 3 | alencon
# Processing Record 23 of Set 3 | takoradi
# Processing Record 24 of Set 3 | kutum
# Processing Record 25 of Set 3 | umm lajj
# Processing Record 26 of Set 3 | castro
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skiping...
# Processing Record 28 of Set 3 | bosaso
# Processing Record 29 of Set 3 | mocuba
# Processing Record 30 of Set 3 | doschatoye
# Processing Record 31 of Set 3 | arlit
# Processing Record 32 of Set 3 | lebu
# Processing Record 33 of Set 3 | iracoubo
# Processing Record 34 of Set 3 | kismayo
# Processing Record 35 of Set 3 | tocopilla
# Processing Record 36 of Set 3 | ponta delgada
# Processing Record 37 of Set 3 | rocha
# Processing Record 38 of Set 3 | saint anthony
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | fomboni
# Processing Record 41 of Set 3 | el paraiso
# Processing Record 42 of Set 3 | yialos
# City not found. Skiping...
# Processing Record 43 of Set 3 | adamas
# Processing Record 44 of Set 3 | tshikapa
# Processing Record 45 of Set 3 | oranjemund
# Processing Record 46 of Set 3 | saint-georges
# Processing Record 47 of Set 3 | lagoa
# Processing Record 48 of Set 3 | nusaybin
# Processing Record 49 of Set 3 | benguela
# Processing Record 50 of Set 3 | sur
# Processing Record 1 of Set 4 | orhei
# Processing Record 2 of Set 4 | misratah
# Processing Record 3 of Set 4 | rio gallegos
# Processing Record 4 of Set 4 | ciudad bolivar
# Processing Record 5 of Set 4 | ubinskoye
# Processing Record 6 of Set 4 | sirfa
# City not found. Skiping...
# Processing Record 7 of Set 4 | hofn
# Processing Record 8 of Set 4 | ponta do sol
# Processing Record 9 of Set 4 | kidal
# Processing Record 10 of Set 4 | pershotravneve
# Processing Record 11 of Set 4 | harnosand
# Processing Record 12 of Set 4 | isla mujeres
# Processing Record 13 of Set 4 | pafos
# Processing Record 14 of Set 4 | harper
# Processing Record 15 of Set 4 | palasa
# Processing Record 16 of Set 4 | havoysund
# Processing Record 17 of Set 4 | uyuni
# Processing Record 18 of Set 4 | farkhor
# Processing Record 19 of Set 4 | amderma
# City not found. Skiping...
# Processing Record 20 of Set 4 | iranshahr
# Processing Record 21 of Set 4 | stornoway
# Processing Record 22 of Set 4 | nola
# Processing Record 23 of Set 4 | iqaluit
# Processing Record 24 of Set 4 | chitral
# Processing Record 25 of Set 4 | alta floresta
# Processing Record 26 of Set 4 | marystown
# Processing Record 27 of Set 4 | gat
# Processing Record 28 of Set 4 | ilulissat
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | anastacio
# Processing Record 31 of Set 4 | buchanan
# Processing Record 32 of Set 4 | sechura
# Processing Record 33 of Set 4 | bambous virieux
# Processing Record 34 of Set 4 | bathsheba
# Processing Record 35 of Set 4 | jadu
# Processing Record 36 of Set 4 | wald
# Processing Record 37 of Set 4 | sabha
# Processing Record 38 of Set 4 | talnakh
# Processing Record 39 of Set 4 | sao sebastiao
# Processing Record 40 of Set 4 | jizan
# Processing Record 41 of Set 4 | severnoye
# Processing Record 42 of Set 4 | vila velha
# Processing Record 43 of Set 4 | daund
# Processing Record 44 of Set 4 | lubumbashi
# Processing Record 45 of Set 4 | touros
# Processing Record 46 of Set 4 | malwan
# City not found. Skiping...
# Processing Record 47 of Set 4 | havelock
# Processing Record 48 of Set 4 | thompson
# Processing Record 49 of Set 4 | torbay
# Processing Record 50 of Set 4 | salmas
# Processing Record 1 of Set 5 | haverfordwest
# Processing Record 2 of Set 5 | kars
# Processing Record 3 of Set 5 | soverato
# Processing Record 4 of Set 5 | sakakah
# Processing Record 5 of Set 5 | cayenne
# Processing Record 6 of Set 5 | shakhrinau
# City not found. Skiping...
# Processing Record 7 of Set 5 | mana
# Processing Record 8 of Set 5 | paramonga
# Processing Record 9 of Set 5 | bubaque
# Processing Record 10 of Set 5 | husavik
# Processing Record 11 of Set 5 | rasskazovo
# Processing Record 12 of Set 5 | emba
# Processing Record 13 of Set 5 | hit
# Processing Record 14 of Set 5 | qandala
# Processing Record 15 of Set 5 | bocas del toro
# Processing Record 16 of Set 5 | asheville
# Processing Record 17 of Set 5 | changji
# Processing Record 18 of Set 5 | nantucket
# Processing Record 19 of Set 5 | guatire
# Processing Record 20 of Set 5 | wabrzezno
# Processing Record 21 of Set 5 | tumannyy
# City not found. Skiping...
# Processing Record 22 of Set 5 | selfoss
# Processing Record 23 of Set 5 | odweyne
# Processing Record 24 of Set 5 | bingol
# Processing Record 25 of Set 5 | narsaq
# Processing Record 26 of Set 5 | chhuikhadan
# Processing Record 27 of Set 5 | dibaya
# City not found. Skiping...
# Processing Record 28 of Set 5 | zlobin
# Processing Record 29 of Set 5 | saint george
# Processing Record 30 of Set 5 | jardim de piranhas
# Processing Record 31 of Set 5 | shipitsyno
# Processing Record 32 of Set 5 | lethem
# Processing Record 33 of Set 5 | sao filipe
# Processing Record 34 of Set 5 | sunyani
# Processing Record 35 of Set 5 | beruni
# City not found. Skiping...
# Processing Record 36 of Set 5 | santa maria
# Processing Record 37 of Set 5 | tessalit
# Processing Record 38 of Set 5 | asyut
# Processing Record 39 of Set 5 | aska
# Processing Record 40 of Set 5 | quelimane
# Processing Record 41 of Set 5 | saint-pierre
# Processing Record 42 of Set 5 | shelburne
# Processing Record 43 of Set 5 | calamar
# Processing Record 44 of Set 5 | karaman
# Processing Record 45 of Set 5 | arkhipo-osipovka
# Processing Record 46 of Set 5 | tarko-sale
# Processing Record 47 of Set 5 | olinda
# Processing Record 48 of Set 5 | caetes
# Processing Record 49 of Set 5 | comodoro rivadavia
# Processing Record 50 of Set 5 | nizhniy baskunchak
# Processing Record 1 of Set 6 | buta
# Processing Record 2 of Set 6 | puri
# Processing Record 3 of Set 6 | shihezi
# Processing Record 4 of Set 6 | nukus
# Processing Record 5 of Set 6 | kibala
# Processing Record 6 of Set 6 | santa isabel do rio negro
# Processing Record 7 of Set 6 | hambantota
# Processing Record 8 of Set 6 | swindon
# Processing Record 9 of Set 6 | kayes
# Processing Record 10 of Set 6 | mogadishu
# Processing Record 11 of Set 6 | witu
# Processing Record 12 of Set 6 | wajid
# Processing Record 13 of Set 6 | marsabit
# Processing Record 14 of Set 6 | lofthus
# Processing Record 15 of Set 6 | tororo
# Processing Record 16 of Set 6 | progreso
# Processing Record 17 of Set 6 | monrovia
# Processing Record 18 of Set 6 | korla
# Processing Record 19 of Set 6 | attawapiskat
# City not found. Skiping...
# Processing Record 20 of Set 6 | mvangue
# Processing Record 21 of Set 6 | inhambane
# Processing Record 22 of Set 6 | puerto madryn
# Processing Record 23 of Set 6 | sile
# Processing Record 24 of Set 6 | bababe
# City not found. Skiping...
# Processing Record 25 of Set 6 | wadi musa
# Processing Record 26 of Set 6 | lahij
# Processing Record 27 of Set 6 | springfield
# Processing Record 28 of Set 6 | rawson
# Processing Record 29 of Set 6 | floresta
# Processing Record 30 of Set 6 | grindavik
# Processing Record 31 of Set 6 | catalina
# Processing Record 32 of Set 6 | bargal
# City not found. Skiping...
# Processing Record 33 of Set 6 | forestville
# Processing Record 34 of Set 6 | chapleau
# Processing Record 35 of Set 6 | dwarka
# Processing Record 36 of Set 6 | vakhrushevo
# Processing Record 37 of Set 6 | kamenka
# Processing Record 38 of Set 6 | yenagoa
# Processing Record 39 of Set 6 | aswan
# Processing Record 40 of Set 6 | grindsted
# Processing Record 41 of Set 6 | manicore
# Processing Record 42 of Set 6 | rundu
# Processing Record 43 of Set 6 | skjervoy
# Processing Record 44 of Set 6 | zabid
# Processing Record 45 of Set 6 | eenhana
# Processing Record 46 of Set 6 | tunceli
# Processing Record 47 of Set 6 | tokonou
# Processing Record 48 of Set 6 | camocim
# Processing Record 49 of Set 6 | marsa matruh
# Processing Record 50 of Set 6 | tarumovka
# Processing Record 1 of Set 7 | tonantins
# Processing Record 2 of Set 7 | gorkovskoye
# City not found. Skiping...
# Processing Record 3 of Set 7 | nara
# Processing Record 4 of Set 7 | mariestad
# Processing Record 5 of Set 7 | dumraon
# Processing Record 6 of Set 7 | luebo
# Processing Record 7 of Set 7 | fonte boa
# Processing Record 8 of Set 7 | yar-sale
# Processing Record 9 of Set 7 | constantine
# Processing Record 10 of Set 7 | araguacu
# Processing Record 11 of Set 7 | geresk
# City not found. Skiping...
# Processing Record 12 of Set 7 | kisangani
# Processing Record 13 of Set 7 | vestmanna
# Processing Record 14 of Set 7 | piacabucu
# Processing Record 15 of Set 7 | coquimbo
# Processing Record 16 of Set 7 | monte alegre
# Processing Record 17 of Set 7 | hamilton
# Processing Record 18 of Set 7 | marfino
# Processing Record 19 of Set 7 | grand gaube
# Processing Record 20 of Set 7 | kiruna
# Processing Record 21 of Set 7 | springdale
# Processing Record 22 of Set 7 | ibra
# Processing Record 23 of Set 7 | waynesboro
# Processing Record 24 of Set 7 | igarka
# Processing Record 25 of Set 7 | thano bula khan
# City not found. Skiping...
# Processing Record 26 of Set 7 | lerwick
# Processing Record 27 of Set 7 | ankara
# Processing Record 28 of Set 7 | olafsvik
# Processing Record 29 of Set 7 | cochrane
# Processing Record 30 of Set 7 | rio claro
# Processing Record 31 of Set 7 | caraquet
# Processing Record 32 of Set 7 | bengkulu
# Processing Record 33 of Set 7 | borama
# City not found. Skiping...
# Processing Record 34 of Set 7 | eyl
# Processing Record 35 of Set 7 | mahebourg
# Processing Record 36 of Set 7 | mehamn
# Processing Record 37 of Set 7 | beisfjord
# Processing Record 38 of Set 7 | filingue
# Processing Record 39 of Set 7 | jardim
# Processing Record 40 of Set 7 | barra do garcas
# Processing Record 41 of Set 7 | ballina
# Processing Record 42 of Set 7 | la primavera
# Processing Record 43 of Set 7 | mbanza-ngungu
# Processing Record 44 of Set 7 | aflao
# Processing Record 45 of Set 7 | melhus
# Processing Record 46 of Set 7 | copiapo
# Processing Record 47 of Set 7 | atar
# Processing Record 48 of Set 7 | chabahar
# Processing Record 49 of Set 7 | goderich
# Processing Record 50 of Set 7 | mrirt
# City not found. Skiping...
# Processing Record 1 of Set 8 | suzun
# Processing Record 2 of Set 8 | kondinskoye
# Processing Record 3 of Set 8 | manavalakurichi
# Processing Record 4 of Set 8 | monroe
# Processing Record 5 of Set 8 | manono
# Processing Record 6 of Set 8 | kachikau
# City not found. Skiping...
# Processing Record 7 of Set 8 | cap malheureux
# Processing Record 8 of Set 8 | ntchisi
# Processing Record 9 of Set 8 | bakchar
# Processing Record 10 of Set 8 | corner brook
# Processing Record 11 of Set 8 | angoche
# Processing Record 12 of Set 8 | marzuq
# Processing Record 13 of Set 8 | cornelio procopio
# Processing Record 14 of Set 8 | addi ugri
# City not found. Skiping...
# Processing Record 15 of Set 8 | tahta
# Processing Record 16 of Set 8 | tonj
# Processing Record 17 of Set 8 | owosso
# Processing Record 18 of Set 8 | jaque
# Processing Record 19 of Set 8 | clarence town
# Processing Record 20 of Set 8 | dingle
# Processing Record 21 of Set 8 | coswig
# Processing Record 22 of Set 8 | angra
# City not found. Skiping...
# Processing Record 23 of Set 8 | arenys de mar
# Processing Record 24 of Set 8 | saint-augustin
# Processing Record 25 of Set 8 | vilhena
# Processing Record 26 of Set 8 | gorodovikovsk
# Processing Record 27 of Set 8 | sao joao da barra
# Processing Record 28 of Set 8 | am timan
# Processing Record 29 of Set 8 | ganganagar
# Processing Record 30 of Set 8 | collierville
# Processing Record 31 of Set 8 | junin
# Processing Record 32 of Set 8 | viedma
# Processing Record 33 of Set 8 | campbellsville
# Processing Record 34 of Set 8 | barcelos
# Processing Record 35 of Set 8 | guajara-mirim
# City not found. Skiping...
# Processing Record 36 of Set 8 | yurginskoye
# Processing Record 37 of Set 8 | high rock
# Processing Record 38 of Set 8 | viligili
# City not found. Skiping...
# Processing Record 39 of Set 8 | turukhansk
# Processing Record 40 of Set 8 | laki
# Processing Record 41 of Set 8 | riyadh
# Processing Record 42 of Set 8 | kaoma
# Processing Record 43 of Set 8 | bandarbeyla
# Processing Record 44 of Set 8 | thunder bay
# Processing Record 45 of Set 8 | hyderabad
# Processing Record 46 of Set 8 | lodja
# Processing Record 47 of Set 8 | eskil
# Processing Record 48 of Set 8 | binga
# Processing Record 49 of Set 8 | porto velho
# Processing Record 50 of Set 8 | mikhaylovka
# Processing Record 1 of Set 9 | sambava
# Processing Record 2 of Set 9 | taburbah
# City not found. Skiping...
# Processing Record 3 of Set 9 | araouane
# Processing Record 4 of Set 9 | kalmunai
# Processing Record 5 of Set 9 | haifa
# Processing Record 6 of Set 9 | sinnamary
# Processing Record 7 of Set 9 | nazare
# Processing Record 8 of Set 9 | najran
# Processing Record 9 of Set 9 | dolores
# Processing Record 10 of Set 9 | tambul
# City not found. Skiping...
# Processing Record 11 of Set 9 | santo antonio do sudoeste
# Processing Record 12 of Set 9 | jarjis
# City not found. Skiping...
# Processing Record 13 of Set 9 | toliary
# City not found. Skiping...
# Processing Record 14 of Set 9 | kytlym
# City not found. Skiping...
# Processing Record 15 of Set 9 | galle
# Processing Record 16 of Set 9 | winchester
# Processing Record 17 of Set 9 | brigantine
# Processing Record 18 of Set 9 | kasongo-lunda
# Processing Record 19 of Set 9 | thomasville
# Processing Record 20 of Set 9 | sumbe
# Processing Record 21 of Set 9 | rognan
# Processing Record 22 of Set 9 | kasli
# Processing Record 23 of Set 9 | jalingo
# Processing Record 24 of Set 9 | ugoofaaru
# Processing Record 25 of Set 9 | west bay
# Processing Record 26 of Set 9 | taltal
# Processing Record 27 of Set 9 | antalaha
# Processing Record 28 of Set 9 | coihaique
# Processing Record 29 of Set 9 | lukovetskiy
# Processing Record 30 of Set 9 | nyakahanga
# Processing Record 31 of Set 9 | auka
# Processing Record 32 of Set 9 | mirpur sakro
# Processing Record 33 of Set 9 | matadi
# Processing Record 34 of Set 9 | przhevalskoye
# Processing Record 35 of Set 9 | kichmengskiy gorodok
# Processing Record 36 of Set 9 | kavaratti
# Processing Record 37 of Set 9 | otavi
# Processing Record 38 of Set 9 | port-cartier
# Processing Record 39 of Set 9 | mazagao
# Processing Record 40 of Set 9 | zhukovo
# Processing Record 41 of Set 9 | fuerte olimpo
# Processing Record 42 of Set 9 | zhob
# Processing Record 43 of Set 9 | gamba
# Processing Record 44 of Set 9 | kembe
# Processing Record 45 of Set 9 | dehloran
# Processing Record 46 of Set 9 | ilebo
# Processing Record 47 of Set 9 | kashi
# Processing Record 48 of Set 9 | amapa
# Processing Record 49 of Set 9 | walvis bay
# Processing Record 50 of Set 9 | sorvag
# City not found. Skiping...
# Processing Record 1 of Set 10 | giddalur
# Processing Record 2 of Set 10 | carnarvon
# Processing Record 3 of Set 10 | taywarah
# Processing Record 4 of Set 10 | coxim
# Processing Record 5 of Set 10 | san lawrenz
# Processing Record 6 of Set 10 | roald
# Processing Record 7 of Set 10 | mandera
# Processing Record 8 of Set 10 | urdzhar
# City not found. Skiping...
# Processing Record 9 of Set 10 | balkhash
# Processing Record 10 of Set 10 | dhidhdhoo
# Processing Record 11 of Set 10 | ankazoabo
# Processing Record 12 of Set 10 | kedrovyy
# Processing Record 13 of Set 10 | karla
# Processing Record 14 of Set 10 | ghiror
# Processing Record 15 of Set 10 | skagastrond
# City not found. Skiping...
# Processing Record 16 of Set 10 | safaqis
# City not found. Skiping...
# Processing Record 17 of Set 10 | neuquen
# Processing Record 18 of Set 10 | jasdan
# Processing Record 19 of Set 10 | marrakesh
# Processing Record 20 of Set 10 | beyneu
# Processing Record 21 of Set 10 | dunkirk
# Processing Record 22 of Set 10 | dasoguz
# Processing Record 23 of Set 10 | porto murtinho
# Processing Record 24 of Set 10 | balkanabat
# Processing Record 25 of Set 10 | solovetskiy
# City not found. Skiping...
# Processing Record 26 of Set 10 | santa cruz de tenerife
# Processing Record 27 of Set 10 | mayumba
# Processing Record 28 of Set 10 | arrecife
# Processing Record 29 of Set 10 | punta de bombon
# Processing Record 30 of Set 10 | atkarsk
# Processing Record 31 of Set 10 | ozinki
# Processing Record 32 of Set 10 | rafai
# Processing Record 33 of Set 10 | vidalia
# Processing Record 34 of Set 10 | karkaralinsk
# City not found. Skiping...
# Processing Record 35 of Set 10 | ormara
# Processing Record 36 of Set 10 | dingli
# Processing Record 37 of Set 10 | castrillon
# Processing Record 38 of Set 10 | ahmadnagar
# Processing Record 39 of Set 10 | namibe
# Processing Record 40 of Set 10 | gazli
# Processing Record 41 of Set 10 | milledgeville
# Processing Record 42 of Set 10 | altamira
# Processing Record 43 of Set 10 | port blair
# Processing Record 44 of Set 10 | vorona
# Processing Record 45 of Set 10 | aflu
# City not found. Skiping...
# Processing Record 46 of Set 10 | assomada
# Processing Record 47 of Set 10 | mumford
# Processing Record 48 of Set 10 | beloha
# Processing Record 49 of Set 10 | wangdiphodrang
# City not found. Skiping...
# Processing Record 50 of Set 10 | autazes
# Processing Record 1 of Set 11 | adrar
# Processing Record 2 of Set 11 | mahbubabad
# Processing Record 3 of Set 11 | entre rios
# Processing Record 4 of Set 11 | carballo
# Processing Record 5 of Set 11 | mongo
# Processing Record 6 of Set 11 | belyy yar
# Processing Record 7 of Set 11 | kourou
# Processing Record 8 of Set 11 | fereydun kenar
# Processing Record 9 of Set 11 | vangaindrano
# Processing Record 10 of Set 11 | soma
# Processing Record 11 of Set 11 | paidha
# Processing Record 12 of Set 11 | loandjili
# Processing Record 13 of Set 11 | mokobeng
# Processing Record 14 of Set 11 | promyshlennaya
# Processing Record 15 of Set 11 | kuttanallur
# City not found. Skiping...
# Processing Record 16 of Set 11 | sarankhola
# Processing Record 17 of Set 11 | pitimbu
# Processing Record 18 of Set 11 | karakol
# Processing Record 19 of Set 11 | samana
# Processing Record 20 of Set 11 | bam
# Processing Record 21 of Set 11 | xai-xai
# Processing Record 22 of Set 11 | la rioja
# Processing Record 23 of Set 11 | sumbawanga
# Processing Record 24 of Set 11 | bumba
# Processing Record 25 of Set 11 | bad mergentheim
# Processing Record 26 of Set 11 | yangambi
# Processing Record 27 of Set 11 | puerto del rosario
# Processing Record 28 of Set 11 | saint-francois
# Processing Record 29 of Set 11 | arvika
# Processing Record 30 of Set 11 | baneasa
# Processing Record 31 of Set 11 | margate
# Processing Record 32 of Set 11 | hoima
# Processing Record 33 of Set 11 | mantua
# Processing Record 34 of Set 11 | san miguel
# Processing Record 35 of Set 11 | nyeri
# Processing Record 36 of Set 11 | varnavino
# Processing Record 37 of Set 11 | patacamaya
# Processing Record 38 of Set 11 | scarborough
# Processing Record 39 of Set 11 | gouyave
# Processing Record 40 of Set 11 | agadez
# Processing Record 41 of Set 11 | gusev
# Processing Record 42 of Set 11 | san rafael
# Processing Record 43 of Set 11 | cherdyn
# Processing Record 44 of Set 11 | lima
# Processing Record 45 of Set 11 | jiddah
# City not found. Skiping...
# Processing Record 46 of Set 11 | parrita
# Processing Record 47 of Set 11 | fallingbostel
# Processing Record 48 of Set 11 | diffa
# Processing Record 49 of Set 11 | la palma
# Processing Record 50 of Set 11 | tapaua
# City not found. Skiping...
# Processing Record 1 of Set 12 | murgab
# Processing Record 2 of Set 12 | sao paulo de olivenca
# Processing Record 3 of Set 12 | camacha
# Processing Record 4 of Set 12 | kardla
# Processing Record 5 of Set 12 | road town
# Processing Record 6 of Set 12 | krasnoselkup
# Processing Record 7 of Set 12 | esmeraldas
# Processing Record 8 of Set 12 | inderborskiy
# City not found. Skiping...
# Processing Record 9 of Set 12 | waldoboro
# Processing Record 10 of Set 12 | tabou
# Processing Record 11 of Set 12 | evans
# Processing Record 12 of Set 12 | guajara
# Processing Record 13 of Set 12 | dharapuram
# Processing Record 14 of Set 12 | george town
# Processing Record 15 of Set 12 | muros
# Processing Record 16 of Set 12 | kozhva
# Processing Record 17 of Set 12 | mortka
# Processing Record 18 of Set 12 | arya
# Processing Record 19 of Set 12 | ostersund
# Processing Record 20 of Set 12 | stratford
# Processing Record 21 of Set 12 | kibondo
# Processing Record 22 of Set 12 | oshnaviyeh
# Processing Record 23 of Set 12 | omboue
# Processing Record 24 of Set 12 | dogondoutchi
# Processing Record 25 of Set 12 | brokopondo
# Processing Record 26 of Set 12 | gollere
# City not found. Skiping...
# Processing Record 27 of Set 12 | kosovska mitrovica
# Processing Record 28 of Set 12 | kirkwall
# Processing Record 29 of Set 12 | burlington
# Processing Record 30 of Set 12 | alice town
# Processing Record 31 of Set 12 | surt
# Processing Record 32 of Set 12 | mitu
# Processing Record 33 of Set 12 | plouzane
# Processing Record 34 of Set 12 | bridgetown
# Processing Record 35 of Set 12 | ninotsminda
# Processing Record 36 of Set 12 | rindal
# Processing Record 37 of Set 12 | ondjiva
# Processing Record 38 of Set 12 | aksarka
# Processing Record 39 of Set 12 | kudahuvadhoo
# Processing Record 40 of Set 12 | paralimni
# Processing Record 41 of Set 12 | zhitikara
# City not found. Skiping...
# Processing Record 42 of Set 12 | columbus
# Processing Record 43 of Set 12 | onega
# Processing Record 44 of Set 12 | karauzyak
# City not found. Skiping...
# Processing Record 45 of Set 12 | tumbotino
# Processing Record 46 of Set 12 | canaries
# Processing Record 47 of Set 12 | dalvik
# Processing Record 48 of Set 12 | sotouboua
# Processing Record 49 of Set 12 | makinsk
# Processing Record 50 of Set 12 | great malvern
# Processing Record 1 of Set 13 | knysna
# Processing Record 2 of Set 13 | chicama
# Processing Record 3 of Set 13 | hwange
# Processing Record 4 of Set 13 | tucuman
# Processing Record 5 of Set 13 | lusambo
# Processing Record 6 of Set 13 | albina
# Processing Record 7 of Set 13 | orocue
# Processing Record 8 of Set 13 | norton shores
# Processing Record 9 of Set 13 | chapada dos guimaraes
# Processing Record 10 of Set 13 | alcaniz
# Processing Record 11 of Set 13 | alexandria
# Processing Record 12 of Set 13 | koroni
# Processing Record 13 of Set 13 | torbat-e jam
# Processing Record 14 of Set 13 | teno
# Processing Record 15 of Set 13 | borlange
# City not found. Skiping...
# Processing Record 16 of Set 13 | hornepayne
# Processing Record 17 of Set 13 | veseloyarsk
# Processing Record 18 of Set 13 | muisne
# Processing Record 19 of Set 13 | purace
# City not found. Skiping...
# Processing Record 20 of Set 13 | sergeyevka
# Processing Record 21 of Set 13 | alta
# Processing Record 22 of Set 13 | sherbakul
# Processing Record 23 of Set 13 | mwense
# Processing Record 24 of Set 13 | marawi
# Processing Record 25 of Set 13 | vestbygda
# City not found. Skiping...
# Processing Record 26 of Set 13 | bongandanga
# Processing Record 27 of Set 13 | senanga
# Processing Record 28 of Set 13 | san clemente
# Processing Record 29 of Set 13 | beroroha
# Processing Record 30 of Set 13 | hvammstangi
# City not found. Skiping...
# Processing Record 31 of Set 13 | domoni
# Processing Record 32 of Set 13 | cajibio
# Processing Record 33 of Set 13 | colares
# Processing Record 34 of Set 13 | mabaruma
# Processing Record 35 of Set 13 | leua
# Processing Record 36 of Set 13 | bajil
# Processing Record 37 of Set 13 | bom jardim
# Processing Record 38 of Set 13 | marquette
# Processing Record 39 of Set 13 | bonfim
# Processing Record 40 of Set 13 | mucuri
# Processing Record 41 of Set 13 | muzhi
# Processing Record 42 of Set 13 | kasempa
# Processing Record 43 of Set 13 | challans
# Processing Record 44 of Set 13 | mitsamiouli
# Processing Record 45 of Set 13 | berlevag
# Processing Record 46 of Set 13 | sozimskiy
# Processing Record 47 of Set 13 | masvingo
# Processing Record 48 of Set 13 | groningen
# Processing Record 49 of Set 13 | moiyabana
# City not found. Skiping...
# Processing Record 50 of Set 13 | visby
# Processing Record 1 of Set 14 | nampula
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)

new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#                City Country                 Date      Lat      Lng  Max Temp  \
# 0    Port Elizabeth      ZA  2022-05-04 15:52:10 -33.9180  25.5701     70.09
# 1       Salinopolis      BR  2022-05-04 15:52:10  -0.6136 -47.3561     81.00
# 2       East London      ZA  2022-05-04 15:52:11 -33.0153  27.9116     70.74
# 3           Ushuaia      AR  2022-05-04 15:52:11 -54.8000 -68.3000     44.22
# 4     Kushchevskaya      RU  2022-05-04 15:52:11  46.5564  39.6386     57.65
# 5  Praia Da Vitoria      PT  2022-05-04 15:52:12  38.7333 -27.0667     67.75
# 6         Maniitsoq      GL  2022-05-04 15:52:12  65.4167 -52.9000     21.22
# 7    Vestmannaeyjar      IS  2022-05-04 15:52:12  63.4427 -20.2734     43.79
# 8   Puerto Quijarro      BO  2022-05-04 15:52:13 -17.7833 -57.7667     79.90
# 9         Jamestown      US  2022-05-04 15:52:13  42.0970 -79.2353     51.03
#
#    Humidity  Cloudiness  Wind Speed
# 0        83           0        4.61
# 1        80          68        4.36
# 2        83           0        4.61
# 3        65          40       20.71
# 4        78         100        4.14
# 5        88          75       13.35
# 6        74          89        3.15
# 7        61           0       18.41
# 8        24          24        4.18
# 9        96         100        5.99

# %%
# Create the output file (csv)

output_data_file = "weather_data/cities.csv"

# Export the City_Data into a csv.

city_data_df.to_csv(output_data_file, index_label = "City_ID")

# %%
# Extract the relevant fields from the DF for plotting

lats = city_data_df["Lat"]

max_temps = city_data_df["Max Temp"]

humidity = city_data_df["Humidity"]

cloudiness = city_data_df["Cloudiness"]

wind_speed = city_data_df["Wind Speed"]

# %%
# %matplotlib notebook

# Build the scatter plot for latitude vs. max temperature

plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidths=1, marker="o",
            alpha= 0.8, label ="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs. Max Temperature "+time.strftime("%x"))

plt.ylabel("Max Temperature (F)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("weather_data/Fig1.png")

# Show plot.

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Build the scatter plot for latitude vs. humidity

plt.scatter(lats,
           humidity,
           edgecolor="black", linewidths=1, marker="o",
            alpha= 0.8, label ="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs. Humidity "+time.strftime("%x"))

plt.ylabel("Humidity(%)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("weather_data/Fig2.png")

# Show plot.

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Build the scatter plot for latitude vs. Cloudiness

plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidths=1, marker="o",
            alpha= 0.8, label ="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs. Cloudiness "+time.strftime("%x"))

plt.ylabel("Cloudiness (%)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("weather_data/Fig3.png")

# Show plot.

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Build the scatter plot for latitude vs. Wind Speed

plt.scatter(lats,
           wind_speed,
           edgecolor="black", linewidths=1, marker="o",
            alpha= 0.8, label ="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs. Wind Speed "+time.strftime("%x"))

plt.ylabel("Wind Speeh (mph)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("weather_data/Fig4.png")

# Show plot.

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Import linregress

from scipy.stats import linregress

# Create a function to create and perform linear regress on the weather data.

# And plot a regression line and the equation with the data.

def plot_linear_regression(x_values,y_values,title,y_label,text_coordinates):
    
    # Run regression on the hemisphere weather data
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
    
    line_eq = "y = " + str(round(slope,2))+"x + " +str(round(intercept,2))
    
    # Create a scatter plot and plot the regression line.
    
    plt.scatter(x_values, y_values)
    
    plt.plot(x_values, regress_values, "r")
    
    # Annotate the text for the line equation
    
    plt.annotate(line_eq, text_coordinates, fontsize=15, color='r')
    
    plt.title(title)
    
    plt.xlabel('Latitude')
    
    plt.ylabel(y_label)
    
    plt.show()

# %%
# Create Northern and Southern Hemisphere dataframes.

northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere.

x_values = northern_hemi_df["Lat"]

y_values = northern_hemi_df["Max Temp"]

# Call the function

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere\nfor Maximum Temperature',
                       'Max Temp', (10,40))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Linear regression on the Southern Hemisphere.

x_values = southern_hemi_df["Lat"]

y_values = southern_hemi_df["Max Temp"]

# Call the function

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere\nfor Maximum Temperature',
                       'Max Temp', (-50,90))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Linear regression on the Northern Hemisphere.

x_values = northern_hemi_df["Lat"]

y_values = northern_hemi_df["Humidity"]

# Call the function

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere\nfor % Humidity',
                       '% Humidity', (40,10))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Linear regression on the Southern Hemisphere.

x_values = southern_hemi_df["Lat"]

y_values = southern_hemi_df["Humidity"]

# Call the function

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere\nfor % Humidity',
                       '% Humidity', (-50,20))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Linear regression on the Northern Hemisphere.

x_values = northern_hemi_df["Lat"]

y_values = northern_hemi_df["Cloudiness"]

# Call the function

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere\nfor % Cloudiness',
                       '% Cloudiness', (10,60))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Linear regression on the Southern Hemisphere.

x_values = southern_hemi_df["Lat"]

y_values = southern_hemi_df["Cloudiness"]

# Call the function

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere\nfor % Cloudiness',
                       '% Cloudiness', (-50,80))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Linear regression on the Northern Hemisphere.

x_values = northern_hemi_df["Lat"]

y_values = northern_hemi_df["Wind Speed"]

# Call the function

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere\nfor Wind Speed',
                       'Wind Speed (mph)', (10,25))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Linear regression on the Southern Hemisphere.

x_values = southern_hemi_df["Lat"]

y_values = southern_hemi_df["Wind Speed"]

# Call the function

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere\nfor Wind Speed',
                       'Wind Speed (mph)', (-55,3))
# Out:
# <img src="data:image/png;base64,..." width="640">
