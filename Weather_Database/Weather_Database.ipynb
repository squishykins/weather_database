# %%
# Import dependencies

import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time

# %%
# Create a set of 2000 random latitudes and longitudes

lats = np.random.uniform(low = -90, high = 90, size = 2000)

lngs = np.random.uniform(low = -90, high = 90, size = 2000)

lats_lngs = zip(lats, lngs)

# %%
# Add the coordinates to a list

coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities

cities = []

# Identify the nearest city for each coordinate

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 772

# %%
# Starting url

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data

city_data = []

# Beginning of the logging.

print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters

record_count = 1

set_count = 1

# Loop through all cities in the list

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging
    
    if (i%50 == 0 and i >= 50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)
    
    # Create endpoint url with each city
    
    city_url = url+"&q="+city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    
    record_count += 1
    
# Run an api request for each of the cities
    try:
        # Parse the JSON and retrieve data
        
        city_weather = requests.get(city_url).json()

                # Parse out the needed data

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list

        city_data.append({"City": city.title(),
                        "Country":city_country,
                        "Lat":city_lat,
                        "Lng":city_lng,
                        "Max Temp":city_max_temp,
                        "Humidity":city_humidity,
                        "Cloudiness":city_clouds,
                        "Wind Speed":city_wind,
                        "Current Description":city_description})
        # If error, skip the city
    except:
        print("City not found. Skipping...")
            
        pass

# Indicate that Data Loading is complete.

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | caravelas
# Processing Record 2 of Set 1 | derzhavinsk
# Processing Record 3 of Set 1 | sancti spiritus
# Processing Record 4 of Set 1 | yining
# Processing Record 5 of Set 1 | pervoye maya
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | arrecife
# Processing Record 8 of Set 1 | boda
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | banikoara
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | kruisfontein
# Processing Record 13 of Set 1 | taltal
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | matara
# Processing Record 16 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | vila velha
# Processing Record 19 of Set 1 | amapa
# Processing Record 20 of Set 1 | maceio
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | vestmannaeyjar
# Processing Record 23 of Set 1 | labelle
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | boddam
# Processing Record 26 of Set 1 | kavaratti
# Processing Record 27 of Set 1 | grand gaube
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | shahpura
# Processing Record 31 of Set 1 | korla
# Processing Record 32 of Set 1 | livingstone
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | ancud
# Processing Record 35 of Set 1 | george town
# Processing Record 36 of Set 1 | walkerburn
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | mogadishu
# Processing Record 40 of Set 1 | talnakh
# Processing Record 41 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | upernavik
# Processing Record 44 of Set 1 | upata
# Processing Record 45 of Set 1 | mananjary
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | cayenne
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | pisco
# Processing Record 50 of Set 1 | lethem
# Processing Record 1 of Set 2 | yar-sale
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 2 | geraldton
# Processing Record 5 of Set 2 | gueret
# Processing Record 6 of Set 2 | skjervoy
# Processing Record 7 of Set 2 | bereda
# Processing Record 8 of Set 2 | dalbandin
# Processing Record 9 of Set 2 | apucarana
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | zherdevka
# Processing Record 12 of Set 2 | naujamiestis
# Processing Record 13 of Set 2 | samana
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | skelleftea
# Processing Record 16 of Set 2 | goya
# Processing Record 17 of Set 2 | stephenville
# Processing Record 18 of Set 2 | ponta do sol
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | shetpe
# Processing Record 21 of Set 2 | pokhara
# Processing Record 22 of Set 2 | mkushi
# Processing Record 23 of Set 2 | beloha
# Processing Record 24 of Set 2 | cabo rojo
# Processing Record 25 of Set 2 | kutum
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 2 | taoudenni
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 2 | rawson
# Processing Record 33 of Set 2 | san juan del sur
# Processing Record 34 of Set 2 | rabo de peixe
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | hobyo
# Processing Record 37 of Set 2 | laguna
# Processing Record 38 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 2 | abonnema
# Processing Record 40 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | kushmurun
# Processing Record 43 of Set 2 | kyzyl-suu
# Processing Record 44 of Set 2 | waddan
# Processing Record 45 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 2 | hamilton
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | saint-pierre
# Processing Record 50 of Set 2 | olonets
# Processing Record 1 of Set 3 | kourou
# Processing Record 2 of Set 3 | skibbereen
# Processing Record 3 of Set 3 | chimoio
# Processing Record 4 of Set 3 | bubaque
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | riberalta
# Processing Record 7 of Set 3 | buenaventura
# Processing Record 8 of Set 3 | victoria
# Processing Record 9 of Set 3 | kamina
# Processing Record 10 of Set 3 | lagoa
# Processing Record 11 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 3 | zholymbet
# Processing Record 13 of Set 3 | filadelfia
# Processing Record 14 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 15 of Set 3 | grindavik
# Processing Record 16 of Set 3 | iqaluit
# Processing Record 17 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 3 | onda
# Processing Record 19 of Set 3 | leeuwarden
# Processing Record 20 of Set 3 | aksay
# Processing Record 21 of Set 3 | pimentel
# Processing Record 22 of Set 3 | rudolstadt
# Processing Record 23 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 3 | maniitsoq
# Processing Record 25 of Set 3 | maridi
# Processing Record 26 of Set 3 | kontagora
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | edgewater
# Processing Record 29 of Set 3 | dahra
# Processing Record 30 of Set 3 | zabkowice slaskie
# Processing Record 31 of Set 3 | padang
# Processing Record 32 of Set 3 | shache
# Processing Record 33 of Set 3 | kiruna
# Processing Record 34 of Set 3 | iskateley
# Processing Record 35 of Set 3 | khorramshahr
# Processing Record 36 of Set 3 | klaksvik
# Processing Record 37 of Set 3 | thinadhoo
# Processing Record 38 of Set 3 | riyadh
# Processing Record 39 of Set 3 | bambous virieux
# Processing Record 40 of Set 3 | bathsheba
# Processing Record 41 of Set 3 | shakhtinsk
# Processing Record 42 of Set 3 | saldanha
# Processing Record 43 of Set 3 | novi ligure
# Processing Record 44 of Set 3 | chiredzi
# Processing Record 45 of Set 3 | sete
# Processing Record 46 of Set 3 | strezhevoy
# Processing Record 47 of Set 3 | santa maria
# Processing Record 48 of Set 3 | pucallpa
# Processing Record 49 of Set 3 | sandwick
# Processing Record 50 of Set 3 | mecca
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | bud
# Processing Record 3 of Set 4 | cartagena
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | strzelce krajenskie
# Processing Record 6 of Set 4 | sabinopolis
# Processing Record 7 of Set 4 | oume
# Processing Record 8 of Set 4 | richards bay
# Processing Record 9 of Set 4 | villaviciosa
# Processing Record 10 of Set 4 | ivdel
# Processing Record 11 of Set 4 | cidreira
# Processing Record 12 of Set 4 | erzurum
# Processing Record 13 of Set 4 | goundam
# Processing Record 14 of Set 4 | garni
# Processing Record 15 of Set 4 | namibe
# Processing Record 16 of Set 4 | detva
# Processing Record 17 of Set 4 | saint-felicien
# Processing Record 18 of Set 4 | venado tuerto
# Processing Record 19 of Set 4 | khash
# Processing Record 20 of Set 4 | sindgi
# Processing Record 21 of Set 4 | berkak
# Processing Record 22 of Set 4 | newtownards
# Processing Record 23 of Set 4 | andenes
# Processing Record 24 of Set 4 | lebu
# Processing Record 25 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 27 of Set 4 | mehamn
# Processing Record 28 of Set 4 | itarema
# Processing Record 29 of Set 4 | gilching
# Processing Record 30 of Set 4 | beisfjord
# Processing Record 31 of Set 4 | khvorostyanka
# Processing Record 32 of Set 4 | tupancireta
# Processing Record 33 of Set 4 | sao joao da barra
# Processing Record 34 of Set 4 | adrar
# Processing Record 35 of Set 4 | oriximina
# Processing Record 36 of Set 4 | flic en flac
# Processing Record 37 of Set 4 | banda aceh
# Processing Record 38 of Set 4 | leninskoye
# Processing Record 39 of Set 4 | hambantota
# Processing Record 40 of Set 4 | faya
# Processing Record 41 of Set 4 | jacareacanga
# Processing Record 42 of Set 4 | bandarbeyla
# Processing Record 43 of Set 4 | puerto colombia
# Processing Record 44 of Set 4 | salalah
# Processing Record 45 of Set 4 | lucapa
# Processing Record 46 of Set 4 | nawada
# Processing Record 47 of Set 4 | marawi
# Processing Record 48 of Set 4 | pangnirtung
# Processing Record 49 of Set 4 | rio gallegos
# Processing Record 50 of Set 4 | sosnogorsk
# Processing Record 1 of Set 5 | vadso
# Processing Record 2 of Set 5 | seminole
# Processing Record 3 of Set 5 | port blair
# Processing Record 4 of Set 5 | bonthe
# Processing Record 5 of Set 5 | alexandria
# Processing Record 6 of Set 5 | kamenka
# Processing Record 7 of Set 5 | borujan
# City not found. Skipping...
# Processing Record 8 of Set 5 | dingle
# Processing Record 9 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 10 of Set 5 | nouadhibou
# Processing Record 11 of Set 5 | codrington
# Processing Record 12 of Set 5 | pitimbu
# Processing Record 13 of Set 5 | alegrete
# Processing Record 14 of Set 5 | eeklo
# Processing Record 15 of Set 5 | takoradi
# Processing Record 16 of Set 5 | mukhtolovo
# Processing Record 17 of Set 5 | tasiilaq
# Processing Record 18 of Set 5 | belmonte
# Processing Record 19 of Set 5 | bet shemesh
# Processing Record 20 of Set 5 | honningsvag
# Processing Record 21 of Set 5 | erseke
# Processing Record 22 of Set 5 | hella
# Processing Record 23 of Set 5 | sao desiderio
# Processing Record 24 of Set 5 | florianopolis
# Processing Record 25 of Set 5 | vardo
# Processing Record 26 of Set 5 | necochea
# Processing Record 27 of Set 5 | bom jesus
# Processing Record 28 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 29 of Set 5 | stornoway
# Processing Record 30 of Set 5 | tivaouane
# Processing Record 31 of Set 5 | plettenberg bay
# Processing Record 32 of Set 5 | albany
# Processing Record 33 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 5 | coquimbo
# Processing Record 35 of Set 5 | bognor regis
# Processing Record 36 of Set 5 | miandrivazo
# Processing Record 37 of Set 5 | ostrovnoy
# Processing Record 38 of Set 5 | arak
# Processing Record 39 of Set 5 | moram
# Processing Record 40 of Set 5 | doge
# Processing Record 41 of Set 5 | ilulissat
# Processing Record 42 of Set 5 | kapoeta
# Processing Record 43 of Set 5 | agdas
# Processing Record 44 of Set 5 | sinjar
# Processing Record 45 of Set 5 | huarmey
# Processing Record 46 of Set 5 | moshenskoye
# Processing Record 47 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 5 | les cayes
# Processing Record 49 of Set 5 | ustyuzhna
# Processing Record 50 of Set 5 | columbus
# Processing Record 1 of Set 6 | igarka
# Processing Record 2 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 6 | yasenskaya
# Processing Record 5 of Set 6 | maldonado
# Processing Record 6 of Set 6 | bronnoysund
# Processing Record 7 of Set 6 | inirida
# Processing Record 8 of Set 6 | oktyabrskoye
# Processing Record 9 of Set 6 | sokolskoye
# Processing Record 10 of Set 6 | inhambane
# Processing Record 11 of Set 6 | rosetta
# Processing Record 12 of Set 6 | bengkulu
# Processing Record 13 of Set 6 | saint anthony
# Processing Record 14 of Set 6 | zheleznodorozhnyy
# Processing Record 15 of Set 6 | antalaha
# Processing Record 16 of Set 6 | maamba
# Processing Record 17 of Set 6 | macenta
# Processing Record 18 of Set 6 | puri
# Processing Record 19 of Set 6 | belyy yar
# Processing Record 20 of Set 6 | araguatins
# City not found. Skipping...
# Processing Record 21 of Set 6 | ajdabiya
# Processing Record 22 of Set 6 | palasa
# Processing Record 23 of Set 6 | puerto asis
# Processing Record 24 of Set 6 | arsk
# Processing Record 25 of Set 6 | rio grande
# Processing Record 26 of Set 6 | salisbury
# Processing Record 27 of Set 6 | mumford
# Processing Record 28 of Set 6 | mabaruma
# Processing Record 29 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 30 of Set 6 | dwarka
# Processing Record 31 of Set 6 | raudeberg
# Processing Record 32 of Set 6 | porbandar
# Processing Record 33 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 34 of Set 6 | trabzon
# Processing Record 35 of Set 6 | sumbe
# Processing Record 36 of Set 6 | anina
# Processing Record 37 of Set 6 | itacare
# Processing Record 38 of Set 6 | narsaq
# Processing Record 39 of Set 6 | hvolsvollur
# Processing Record 40 of Set 6 | aripuana
# Processing Record 41 of Set 6 | senneterre
# Processing Record 42 of Set 6 | cockburn town
# Processing Record 43 of Set 6 | matsanga
# City not found. Skipping...
# Processing Record 44 of Set 6 | duz
# City not found. Skipping...
# Processing Record 45 of Set 6 | labe
# Processing Record 46 of Set 6 | ustka
# Processing Record 47 of Set 6 | coihaique
# Processing Record 48 of Set 6 | olafsvik
# Processing Record 49 of Set 6 | huntsville
# Processing Record 50 of Set 6 | parana
# Processing Record 1 of Set 7 | boa vista
# Processing Record 2 of Set 7 | mitu
# Processing Record 3 of Set 7 | georgiyevskoye
# Processing Record 4 of Set 7 | sharjah
# Processing Record 5 of Set 7 | ampere
# Processing Record 6 of Set 7 | larreynaga
# Processing Record 7 of Set 7 | megion
# Processing Record 8 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 9 of Set 7 | springbok
# Processing Record 10 of Set 7 | qaqortoq
# Processing Record 11 of Set 7 | tutoia
# Processing Record 12 of Set 7 | saquarema
# Processing Record 13 of Set 7 | iisalmi
# Processing Record 14 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 7 | bonavista
# Processing Record 16 of Set 7 | junagadh
# Processing Record 17 of Set 7 | leca da palmeira
# Processing Record 18 of Set 7 | nanortalik
# Processing Record 19 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 7 | mooi river
# City not found. Skipping...
# Processing Record 21 of Set 7 | sao paulo de olivenca
# Processing Record 22 of Set 7 | marabba
# Processing Record 23 of Set 7 | jambol
# City not found. Skipping...
# Processing Record 24 of Set 7 | ylivieska
# Processing Record 25 of Set 7 | maragogi
# Processing Record 26 of Set 7 | los llanos de aridane
# Processing Record 27 of Set 7 | saint-augustin
# Processing Record 28 of Set 7 | camana
# Processing Record 29 of Set 7 | bar harbor
# Processing Record 30 of Set 7 | tabou
# Processing Record 31 of Set 7 | buzmeyin
# Processing Record 32 of Set 7 | ahero
# Processing Record 33 of Set 7 | port ellen
# City not found. Skipping...
# Processing Record 34 of Set 7 | kurchum
# Processing Record 35 of Set 7 | hun
# Processing Record 36 of Set 7 | vuktyl
# Processing Record 37 of Set 7 | santa rosa
# Processing Record 38 of Set 7 | vila franca do campo
# Processing Record 39 of Set 7 | little current
# Processing Record 40 of Set 7 | nacala
# Processing Record 41 of Set 7 | umm lajj
# Processing Record 42 of Set 7 | volcan
# Processing Record 43 of Set 7 | berlevag
# Processing Record 44 of Set 7 | opuwo
# Processing Record 45 of Set 7 | port-gentil
# Processing Record 46 of Set 7 | sorland
# Processing Record 47 of Set 7 | bani walid
# Processing Record 48 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 49 of Set 7 | oranjestad
# Processing Record 50 of Set 7 | anar darreh
# City not found. Skipping...
# Processing Record 1 of Set 8 | husavik
# Processing Record 2 of Set 8 | neuquen
# Processing Record 3 of Set 8 | ust-tsilma
# Processing Record 4 of Set 8 | kathmandu
# Processing Record 5 of Set 8 | makurdi
# Processing Record 6 of Set 8 | afanasyevo
# City not found. Skipping...
# Processing Record 7 of Set 8 | puerto carreno
# Processing Record 8 of Set 8 | jalu
# Processing Record 9 of Set 8 | sholavandan
# City not found. Skipping...
# Processing Record 10 of Set 8 | sosua
# Processing Record 11 of Set 8 | thompson
# Processing Record 12 of Set 8 | deogarh
# Processing Record 13 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 14 of Set 8 | sandnessjoen
# Processing Record 15 of Set 8 | cerqueira cesar
# Processing Record 16 of Set 8 | san lorenzo
# Processing Record 17 of Set 8 | hofn
# Processing Record 18 of Set 8 | kalemie
# Processing Record 19 of Set 8 | shorkot
# Processing Record 20 of Set 8 | albanel
# Processing Record 21 of Set 8 | umm kaddadah
# Processing Record 22 of Set 8 | kermanshah
# Processing Record 23 of Set 8 | buchanan
# Processing Record 24 of Set 8 | puerto baquerizo moreno
# Processing Record 25 of Set 8 | el carmen
# Processing Record 26 of Set 8 | tukrah
# Processing Record 27 of Set 8 | vallentuna
# Processing Record 28 of Set 8 | nahavand
# Processing Record 29 of Set 8 | catamarca
# Processing Record 30 of Set 8 | soria
# Processing Record 31 of Set 8 | road town
# Processing Record 32 of Set 8 | nizwa
# Processing Record 33 of Set 8 | aguimes
# Processing Record 34 of Set 8 | khandbari
# Processing Record 35 of Set 8 | kvam
# Processing Record 36 of Set 8 | kyabe
# Processing Record 37 of Set 8 | farsund
# Processing Record 38 of Set 8 | atar
# Processing Record 39 of Set 8 | beyneu
# Processing Record 40 of Set 8 | dhidhdhoo
# Processing Record 41 of Set 8 | sinnamary
# Processing Record 42 of Set 8 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 43 of Set 8 | salaverry
# Processing Record 44 of Set 8 | baza
# Processing Record 45 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 8 | margate
# Processing Record 47 of Set 8 | westport
# Processing Record 48 of Set 8 | salym
# Processing Record 49 of Set 8 | saint-francois
# Processing Record 50 of Set 8 | visby
# Processing Record 1 of Set 9 | tenkodogo
# Processing Record 2 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 9 | trelew
# Processing Record 4 of Set 9 | peniche
# Processing Record 5 of Set 9 | mbaiki
# Processing Record 6 of Set 9 | ushtobe
# Processing Record 7 of Set 9 | rey bouba
# Processing Record 8 of Set 9 | the valley
# Processing Record 9 of Set 9 | ituverava
# Processing Record 10 of Set 9 | vestmanna
# Processing Record 11 of Set 9 | tanout
# Processing Record 12 of Set 9 | parabel
# Processing Record 13 of Set 9 | verkhnyaya inta
# Processing Record 14 of Set 9 | chama
# Processing Record 15 of Set 9 | melilla
# Processing Record 16 of Set 9 | paamiut
# Processing Record 17 of Set 9 | westerland
# Processing Record 18 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 9 | fagernes
# Processing Record 20 of Set 9 | cap malheureux
# Processing Record 21 of Set 9 | san francisco
# Processing Record 22 of Set 9 | ulcinj
# Processing Record 23 of Set 9 | karaton
# Processing Record 24 of Set 9 | sarrebourg
# Processing Record 25 of Set 9 | darnah
# Processing Record 26 of Set 9 | marsh harbour
# Processing Record 27 of Set 9 | san ignacio
# Processing Record 28 of Set 9 | omboue
# Processing Record 29 of Set 9 | quatre cocos
# Processing Record 30 of Set 9 | sakakah
# Processing Record 31 of Set 9 | goderich
# Processing Record 32 of Set 9 | alta floresta
# Processing Record 33 of Set 9 | aksaray
# Processing Record 34 of Set 9 | nantucket
# Processing Record 35 of Set 9 | besikduzu
# Processing Record 36 of Set 9 | starodub
# Processing Record 37 of Set 9 | karlskoga
# Processing Record 38 of Set 9 | mamou
# Processing Record 39 of Set 9 | talcahuano
# Processing Record 40 of Set 9 | barreirinhas
# Processing Record 41 of Set 9 | vorukh
# Processing Record 42 of Set 9 | dapaong
# Processing Record 43 of Set 9 | vozhega
# Processing Record 44 of Set 9 | jibuti
# Processing Record 45 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 9 | neka
# Processing Record 47 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 48 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 49 of Set 9 | puerto el triunfo
# Processing Record 50 of Set 9 | takab
# Processing Record 1 of Set 10 | salinopolis
# Processing Record 2 of Set 10 | puerto del rosario
# Processing Record 3 of Set 10 | bogyiszlo
# Processing Record 4 of Set 10 | lapua
# Processing Record 5 of Set 10 | tsogni
# Processing Record 6 of Set 10 | bolshiye uki
# City not found. Skipping...
# Processing Record 7 of Set 10 | marzuq
# Processing Record 8 of Set 10 | panama city
# Processing Record 9 of Set 10 | nhamunda
# Processing Record 10 of Set 10 | changji
# Processing Record 11 of Set 10 | guarapari
# Processing Record 12 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 13 of Set 10 | najran
# Processing Record 14 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 15 of Set 10 | rypefjord
# Processing Record 16 of Set 10 | chardara
# Processing Record 17 of Set 10 | mangan
# Processing Record 18 of Set 10 | badlapur
# Processing Record 19 of Set 10 | qostanay
# Processing Record 20 of Set 10 | paulo afonso
# Processing Record 21 of Set 10 | bangui
# Processing Record 22 of Set 10 | bardiyah
# Processing Record 23 of Set 10 | marsta
# Processing Record 24 of Set 10 | sindor
# Processing Record 25 of Set 10 | is
# City not found. Skipping...
# Processing Record 26 of Set 10 | mbekenyera
# Processing Record 27 of Set 10 | saint-georges
# Processing Record 28 of Set 10 | atasu
# Processing Record 29 of Set 10 | puerto madryn
# Processing Record 30 of Set 10 | lusambo
# Processing Record 31 of Set 10 | mbanza-ngungu
# Processing Record 32 of Set 10 | elat
# Processing Record 33 of Set 10 | kemise
# Processing Record 34 of Set 10 | bull savanna
# Processing Record 35 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 36 of Set 10 | aswan
# Processing Record 37 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 10 | polunochnoye
# Processing Record 39 of Set 10 | jalalabad
# Processing Record 40 of Set 10 | weston
# Processing Record 41 of Set 10 | ureki
# Processing Record 42 of Set 10 | batsfjord
# Processing Record 43 of Set 10 | luanda
# Processing Record 44 of Set 10 | gudiyattam
# City not found. Skipping...
# Processing Record 45 of Set 10 | seydi
# Processing Record 46 of Set 10 | castro
# Processing Record 47 of Set 10 | paramonga
# Processing Record 48 of Set 10 | kuytun
# Processing Record 49 of Set 10 | lundazi
# Processing Record 50 of Set 10 | kalmunai
# Processing Record 1 of Set 11 | dagana
# Processing Record 2 of Set 11 | khabary
# Processing Record 3 of Set 11 | shakiso
# Processing Record 4 of Set 11 | ust-kulom
# Processing Record 5 of Set 11 | karachev
# Processing Record 6 of Set 11 | manta
# Processing Record 7 of Set 11 | salinas
# Processing Record 8 of Set 11 | sarab
# Processing Record 9 of Set 11 | basoko
# Processing Record 10 of Set 11 | kirkuk
# Processing Record 11 of Set 11 | raga
# Processing Record 12 of Set 11 | kudahuvadhoo
# Processing Record 13 of Set 11 | olinda
# Processing Record 14 of Set 11 | kasongo-lunda
# Processing Record 15 of Set 11 | vagamo
# Processing Record 16 of Set 11 | haputale
# Processing Record 17 of Set 11 | lahij
# Processing Record 18 of Set 11 | iquique
# Processing Record 19 of Set 11 | abu dhabi
# Processing Record 20 of Set 11 | mitsamiouli
# Processing Record 21 of Set 11 | leh
# Processing Record 22 of Set 11 | iracoubo
# Processing Record 23 of Set 11 | crewe
# Processing Record 24 of Set 11 | bilma
# Processing Record 25 of Set 11 | dahuk
# Processing Record 26 of Set 11 | tazovskiy
# Processing Record 27 of Set 11 | senanga
# Processing Record 28 of Set 11 | jilib
# Processing Record 29 of Set 11 | soyo
# Processing Record 30 of Set 11 | lerwick
# Processing Record 31 of Set 11 | lisakovsk
# Processing Record 32 of Set 11 | dombarovskiy
# Processing Record 33 of Set 11 | waw
# Processing Record 34 of Set 11 | touros
# Processing Record 35 of Set 11 | riohacha
# Processing Record 36 of Set 11 | kumluca
# Processing Record 37 of Set 11 | yenagoa
# Processing Record 38 of Set 11 | mwinilunga
# Processing Record 39 of Set 11 | port hawkesbury
# Processing Record 40 of Set 11 | durban
# Processing Record 41 of Set 11 | kigorobya
# Processing Record 42 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 43 of Set 11 | lugazi
# Processing Record 44 of Set 11 | imbituba
# Processing Record 45 of Set 11 | monrovia
# Processing Record 46 of Set 11 | conceicao da barra
# Processing Record 47 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 48 of Set 11 | araguaina
# Processing Record 49 of Set 11 | karema
# Processing Record 50 of Set 11 | port-cartier
# Processing Record 1 of Set 12 | kortkeros
# Processing Record 2 of Set 12 | tonj
# Processing Record 3 of Set 12 | alta gracia
# Processing Record 4 of Set 12 | batticaloa
# Processing Record 5 of Set 12 | duzce
# Processing Record 6 of Set 12 | rio verde de mato grosso
# Processing Record 7 of Set 12 | kikwit
# Processing Record 8 of Set 12 | vargem grande
# Processing Record 9 of Set 12 | matagami
# Processing Record 10 of Set 12 | syracuse
# Processing Record 11 of Set 12 | zadar
# Processing Record 12 of Set 12 | morondava
# Processing Record 13 of Set 12 | lar gerd
# City not found. Skipping...
# Processing Record 14 of Set 12 | grand baie
# Processing Record 15 of Set 12 | walvis bay
# Processing Record 16 of Set 12 | barra do garcas
# Processing Record 17 of Set 12 | dera din panah
# City not found. Skipping...
# Processing Record 18 of Set 12 | khangah dogran
# Processing Record 19 of Set 12 | antofagasta
# Processing Record 20 of Set 12 | ponta pora
# Processing Record 21 of Set 12 | werda
# Processing Record 22 of Set 12 | oparino
# Processing Record 23 of Set 12 | aasiaat
# Processing Record 24 of Set 12 | synya
# Processing Record 25 of Set 12 | sisimiut
# Processing Record 26 of Set 12 | gryazi
# Processing Record 27 of Set 12 | siguiri
# Processing Record 28 of Set 12 | saint-pacome
# City not found. Skipping...
# Processing Record 29 of Set 12 | san luis
# Processing Record 30 of Set 12 | sarakhs
# Processing Record 31 of Set 12 | cazaje
# City not found. Skipping...
# Processing Record 32 of Set 12 | pinega
# Processing Record 33 of Set 12 | hualmay
# Processing Record 34 of Set 12 | tel aviv-yafo
# Processing Record 35 of Set 12 | bodden town
# Processing Record 36 of Set 12 | handwara
# City not found. Skipping...
# Processing Record 37 of Set 12 | corralillo
# Processing Record 38 of Set 12 | helsinki
# Processing Record 39 of Set 12 | syasstroy
# Processing Record 40 of Set 12 | skovde
# City not found. Skipping...
# Processing Record 41 of Set 12 | kolosovka
# Processing Record 42 of Set 12 | siavonga
# Processing Record 43 of Set 12 | alghero
# Processing Record 44 of Set 12 | ugoofaaru
# Processing Record 45 of Set 12 | rafsanjan
# Processing Record 46 of Set 12 | hawalli
# Processing Record 47 of Set 12 | pedro betancourt
# Processing Record 48 of Set 12 | lasa
# Processing Record 49 of Set 12 | oranjemund
# Processing Record 50 of Set 12 | guanica
# Processing Record 1 of Set 13 | anderson
# Processing Record 2 of Set 13 | nuuk
# Processing Record 3 of Set 13 | severnyy
# Processing Record 4 of Set 13 | baghdad
# Processing Record 5 of Set 13 | lazurne
# Processing Record 6 of Set 13 | viedma
# Processing Record 7 of Set 13 | eyl
# Processing Record 8 of Set 13 | aquiraz
# Processing Record 9 of Set 13 | isabela
# Processing Record 10 of Set 13 | popesti
# Processing Record 11 of Set 13 | nicoya
# Processing Record 12 of Set 13 | riviere-au-renard
# Processing Record 13 of Set 13 | dabat
# Processing Record 14 of Set 13 | samsun
# Processing Record 15 of Set 13 | dakar
# Processing Record 16 of Set 13 | chepareria
# Processing Record 17 of Set 13 | katsiveli
# City not found. Skipping...
# Processing Record 18 of Set 13 | voyvozh
# Processing Record 19 of Set 13 | tyazhinskiy
# Processing Record 20 of Set 13 | semey
# Processing Record 21 of Set 13 | arlit
# Processing Record 22 of Set 13 | bindura
# Processing Record 23 of Set 13 | buraydah
# Processing Record 24 of Set 13 | malanje
# Processing Record 25 of Set 13 | ypsonas
# Processing Record 26 of Set 13 | bowling green
# Processing Record 27 of Set 13 | rundu
# Processing Record 28 of Set 13 | puerto leguizamo
# Processing Record 29 of Set 13 | arroyo
# Processing Record 30 of Set 13 | teguise
# Processing Record 31 of Set 13 | lawrenceburg
# Processing Record 32 of Set 13 | sayyan
# Processing Record 33 of Set 13 | charlestown
# Processing Record 34 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 35 of Set 13 | miramar
# Processing Record 36 of Set 13 | progreso
# Processing Record 37 of Set 13 | chapleau
# Processing Record 38 of Set 13 | bobovdol
# Processing Record 39 of Set 13 | kita
# Processing Record 40 of Set 13 | nikki
# Processing Record 41 of Set 13 | madras
# Processing Record 42 of Set 13 | kismayo
# Processing Record 43 of Set 13 | ayorou
# Processing Record 44 of Set 13 | buncrana
# Processing Record 45 of Set 13 | gorele
# Processing Record 46 of Set 13 | spas-demensk
# Processing Record 47 of Set 13 | tocopilla
# Processing Record 48 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 49 of Set 13 | ardesen
# Processing Record 50 of Set 13 | boundiali
# Processing Record 1 of Set 14 | cape coast
# Processing Record 2 of Set 14 | wattegama
# Processing Record 3 of Set 14 | springdale
# Processing Record 4 of Set 14 | cuenca
# Processing Record 5 of Set 14 | pachmarhi
# Processing Record 6 of Set 14 | jatai
# Processing Record 7 of Set 14 | urengoy
# Processing Record 8 of Set 14 | sao joao batista
# Processing Record 9 of Set 14 | oksfjord
# Processing Record 10 of Set 14 | san lawrenz
# Processing Record 11 of Set 14 | sabana de torres
# Processing Record 12 of Set 14 | burica
# City not found. Skipping...
# Processing Record 13 of Set 14 | shelburne
# Processing Record 14 of Set 14 | odweyne
# Processing Record 15 of Set 14 | kobojango
# City not found. Skipping...
# Processing Record 16 of Set 14 | nyandoma
# Processing Record 17 of Set 14 | gweru
# Processing Record 18 of Set 14 | kulgam
# Processing Record 19 of Set 14 | arcachon
# Processing Record 20 of Set 14 | colesberg
# Processing Record 21 of Set 14 | murgab
# Processing Record 22 of Set 14 | proddatur
# Processing Record 23 of Set 14 | fort-shevchenko
# Processing Record 24 of Set 14 | chapais
# Processing Record 25 of Set 14 | edd
# Processing Record 26 of Set 14 | saurimo
# Processing Record 27 of Set 14 | mahibadhoo
# Processing Record 28 of Set 14 | ponta delgada
# Processing Record 29 of Set 14 | afsin
# Processing Record 30 of Set 14 | ust-shonosha
# Processing Record 31 of Set 14 | kohat
# Processing Record 32 of Set 14 | linares
# Processing Record 33 of Set 14 | bukama
# Processing Record 34 of Set 14 | arkhangelskoye
# Processing Record 35 of Set 14 | tabuk
# Processing Record 36 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 37 of Set 14 | vilhena
# Processing Record 38 of Set 14 | rocha
# Processing Record 39 of Set 14 | borlange
# City not found. Skipping...
# Processing Record 40 of Set 14 | praia
# Processing Record 41 of Set 14 | bahar
# Processing Record 42 of Set 14 | sangueya
# Processing Record 43 of Set 14 | mirnyy
# Processing Record 44 of Set 14 | caraballeda
# Processing Record 45 of Set 14 | kawambwa
# Processing Record 46 of Set 14 | calama
# Processing Record 47 of Set 14 | sesheke
# Processing Record 48 of Set 14 | lannion
# Processing Record 49 of Set 14 | chabahar
# Processing Record 50 of Set 14 | asmar
# Processing Record 1 of Set 15 | san andres
# Processing Record 2 of Set 15 | axim
# Processing Record 3 of Set 15 | avezzano
# Processing Record 4 of Set 15 | krasnoselkup
# Processing Record 5 of Set 15 | kongolo
# Processing Record 6 of Set 15 | krasnogorskoye
# Processing Record 7 of Set 15 | parrita
# Processing Record 8 of Set 15 | blagoyevo
# Processing Record 9 of Set 15 | gimbi
# Processing Record 10 of Set 15 | ballina
# Processing Record 11 of Set 15 | matamba
# Processing Record 12 of Set 15 | nyazepetrovsk
# Processing Record 13 of Set 15 | ayagoz
# Processing Record 14 of Set 15 | boende
# Processing Record 15 of Set 15 | bousso
# Processing Record 16 of Set 15 | narasimharajapura
# Processing Record 17 of Set 15 | abay
# Processing Record 18 of Set 15 | awbari
# Processing Record 19 of Set 15 | roros
# Processing Record 20 of Set 15 | uzhur
# Processing Record 21 of Set 15 | sinnai
# Processing Record 22 of Set 15 | uddevalla
# Processing Record 23 of Set 15 | ambilobe
# Processing Record 24 of Set 15 | cabedelo
# Processing Record 25 of Set 15 | paidha
# Processing Record 26 of Set 15 | nohar
# Processing Record 27 of Set 15 | cheremushskiy
# Processing Record 28 of Set 15 | soure
# Processing Record 29 of Set 15 | saint simons
# Processing Record 30 of Set 15 | virginia beach
# Processing Record 31 of Set 15 | havoysund
# Processing Record 32 of Set 15 | yalta
# Processing Record 33 of Set 15 | traverse city
# Processing Record 34 of Set 15 | diebougou
# Processing Record 35 of Set 15 | bobingen
# Processing Record 36 of Set 15 | corn island
# Processing Record 37 of Set 15 | sandy bay
# Processing Record 38 of Set 15 | kabalo
# Processing Record 39 of Set 15 | sidi ali
# Processing Record 40 of Set 15 | nekhayevskiy
# Processing Record 41 of Set 15 | baeza
# Processing Record 42 of Set 15 | paranaiba
# Processing Record 43 of Set 15 | requena
# Processing Record 44 of Set 15 | gravdal
# Processing Record 45 of Set 15 | amos
# Processing Record 46 of Set 15 | kembe
# Processing Record 47 of Set 15 | xuddur
# Processing Record 48 of Set 15 | kanye
# Processing Record 49 of Set 15 | kajaani
# Processing Record 50 of Set 15 | khor
# Processing Record 1 of Set 16 | kirkland lake
# Processing Record 2 of Set 16 | general roca
# Processing Record 3 of Set 16 | muli
# Processing Record 4 of Set 16 | san miguel
# Processing Record 5 of Set 16 | izberbash
# Processing Record 6 of Set 16 | monte carmelo
# Processing Record 7 of Set 16 | havelock
# Processing Record 8 of Set 16 | groningen
# Processing Record 9 of Set 16 | dudinka
# Processing Record 10 of Set 16 | san cristobal
# Processing Record 11 of Set 16 | sopo
# Processing Record 12 of Set 16 | moose factory
# Processing Record 13 of Set 16 | manaure
# Processing Record 14 of Set 16 | energetik
# Processing Record 15 of Set 16 | muisne
# Processing Record 16 of Set 16 | panaba
# Processing Record 17 of Set 16 | gazojak
# Processing Record 18 of Set 16 | kalabo
# Processing Record 19 of Set 16 | novaya ladoga
# Processing Record 20 of Set 16 | trincomalee
# Processing Record 21 of Set 16 | bocas del toro
# Processing Record 22 of Set 16 | kungsbacka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a DataFrame

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Caravelas      BR -17.7125  -39.2481     75.25        87          64
# 1      Derzhavinsk      KZ  51.1000   66.3167     42.71        44          95
# 2  Sancti Spiritus      CU  21.9297  -79.4425     82.49        66          33
# 3           Yining      CN  29.0361  114.5636     71.13        80         100
# 4     Pervoye Maya      RU  56.1640   44.7196     39.31        76          47
# 5          Ushuaia      AR -54.8000  -68.3000     42.46        65          40
# 6         Arrecife      ES  28.9630  -13.5477     66.18        82          20
# 7             Boda      CF   4.3189   17.4695     71.85        95          99
# 8        Banikoara      BJ  11.2985    2.4386     85.17        54          98
# 9        Hithadhoo      MV  -0.6000   73.0833     83.39        76          82
#
#    Wind Speed Current Description
# 0        2.66       broken clouds
# 1       13.33     overcast clouds
# 2        6.73          light rain
# 3        0.83     overcast clouds
# 4        7.87    scattered clouds
# 5       20.71    scattered clouds
# 6       13.80          few clouds
# 7        2.04          light rain
# 8        7.65     overcast clouds
# 9       15.37       broken clouds

# %%
# Create output file (csv)

output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city data into a csv

city_data_df.to_csv(output_data_file, index_label = "City_ID")
